# %%
# !pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in /usr/local/lib/python3.10/dist-packages (0.4.0)

# %%
import pandas as pd
import numpy as np
import random
from gender_guesser.detector import Detector

# %%
df = pd.read_csv('/content/sample_data/nombres_españoles.csv', sep = ';', header = None)
df = df.rename(columns={0: 'nombre', 1: 'apellido'})

# %%
df['edad'] = np.random.randint(65, 100, 50000)
df['discapacidad'] = np.random.randint(0, 2, 50000)
df['pension'] = np.random.randint(10963.40, 42829.29, 50000)
df['familia_numerosa'] = np.random.randint(0, 2, 50000)
df['edad_hijo'] = None
df['trabaja_hijo'] = None

fam_num_index = df[df['familia_numerosa'] == 1].index
for i in (fam_num_index):
    a = len(fam_num_index)
    df['edad_hijo'][i] = np.random.randint(15, 26)

hijo_mayor_index = df[df['edad_hijo'] > 20].index
for i in (hijo_mayor_index):
    a = len(hijo_mayor_index)
    df['trabaja_hijo'][i] = np.random.randint(0, 2)

df['lista_espera'] = np.random.randint(0, 3, 50000)

df['estado_civil'] = None
estados = ['soltero/a', 'casado/a', 'viudo/a']
for i in (df.index):
    df['estado_civil'][i] = random.choice(estados)

df['años_ant'] = np.random.randint(0, 3, 50000)
df['vehiculo'] = np.random.randint(0, 2, 50000)
df['hab_individual'] = np.random.randint(0, 2, 50000)

df['mobilidad'] = None
mobilidad = ['perfecta', 'media', 'limitada']
for i in (df.index):
    df['mobilidad'][i] = random.choice(mobilidad)

df['enfermedad'] = None
enfermedad = ['None', 'terminal']
enfermedad = ['None'] * 99 + ['terminal'] * 1
for i in (df.index):
    df['enfermedad'][i] = random.choice(enfermedad)

df['sexo'] = None
gender_detector = Detector()
df['nombre'] = df['nombre'].astype('str')
df['nombre'] = df['nombre'].apply(lambda x: x.title())
df['apellido'] = df['apellido'].astype('str')
df['apellido'] = df['apellido'].apply(lambda x: x.title())
for i in (df.index):
    df['sexo'][i] = gender_detector.get_gender(df['nombre'][i])

df['trabajo'] = None
trabajos = [
    "Médico",
    "Enfermero/a",
    "Profesor/a",
    "Ingeniero/a",
    "Abogado/a",
    "Arquitecto/a",
    "Administrativo/a",
    "Comercial/Vendedor/a",
    "Electricista",
    "Fontanero/a",
    "Programador/a informático/a",
    "Diseñador/a gráfico/a",
    "Carpintero/a",
    "Fontanero/a",
    "Cocinero/a",
    "Camarero/a",
    "Agricultor/a",
    "Peluquero/a",
    "Fontanero/a",
    "Operario/a de fábrica"
]
for i in (df.index):
    df['trabajo'][i] = random.choice(trabajos)
# Out:
# <ipython-input-13-677c405aa21c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['edad_hijo'][i] = np.random.randint(15, 26)
# <ipython-input-13-677c405aa21c>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['trabaja_hijo'][i] = np.random.randint(0, 2)
# <ipython-input-13-677c405aa21c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['estado_civil'][i] = random.choice(estados)
# <ipython-input-13-677c405aa21c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mobilidad'][i] = random.choice(mobilidad)
# <ipython-input-13-677c405aa21c>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['enfermedad'][i] = random.choice(enfermedad)
# <ipython-input-13-677c405aa21c>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sexo'][i] = gender_detector.get_gender(df['nombre'][i])
# <ipython-input-13-677c405aa21c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['trabajo'][i] = random.choice(trabajos)

# %%
df['pension'] = np.random.randint(6784.54, 42829.29, 50000)

# %%
# Out:
#             nombre     apellido  edad  discapacidad  pension  \
# 0          Antonio   Sannicolas    70             1    37597
# 1             Jose  Olloquiegui    99             0    13842
# 2           Manuel       Vinent    68             1    23492
# 3        Francisco    Francesch    76             1    37738
# 4             Juan     Calcines    96             0     9287
# ...            ...          ...   ...           ...      ...
# 49995        Tomas      Bu√Ëuel    89             0     9064
# 49996      Agustin      Luchena    86             0    21860
# 49997    Guillermo      Perdomo    65             1    36849
# 49998      Gabriel     Baraldes    84             0    28574
# 49999  Jose Miguel       Goiria    90             1    15732
#
#        familia_numerosa edad_hijo trabaja_hijo  lista_espera estado_civil  \
# 0                     1        22            1             0     casado/a
# 1                     0      None         None             2     casado/a
# 2                     0      None         None             0    soltero/a
# 3                     1        15         None             2     casado/a
# 4                     0      None         None             0      viudo/a
# ...                 ...       ...          ...           ...          ...
# 49995                 0      None         None             2     casado/a
# 49996                 1        17         None             1    soltero/a
# 49997                 0      None         None             2     casado/a
# 49998                 0      None         None             0     casado/a
# 49999                 0      None         None             0     casado/a
#
#        años_ant  vehiculo  hab_individual mobilidad enfermedad     sexo  \
# 0             1         1               1     media       None     male
# 1             2         1               1     media       None     male
# 2             0         0               0     media       None     male
# 3             1         1               1  limitada       None     male
# 4             1         1               0  limitada       None     male
# ...         ...       ...             ...       ...        ...      ...
# 49995         0         1               0     media       None     male
# 49996         0         0               1  perfecta       None     male
# 49997         2         1               0  perfecta       None     male
# 49998         2         0               0     media       None     male
# 49999         0         1               1  limitada       None  unknown
#
#                     trabajo
# 0                Camarero/a
# 1               Fontanero/a
# 2                Profesor/a
# 3              Electricista
# 4               Enfermero/a
# ...                     ...
# 49995  Comercial/Vendedor/a
# 49996  Comercial/Vendedor/a
# 49997            Cocinero/a
# 49998           Fontanero/a
# 49999            Camarero/a
#
# [50000 rows x 17 columns]

# %%
bins = [6774.54, 12600, 14700, 16800, 18900, 21000, 23100, 25200, 27300, 29400, float('inf')]
etiquetas = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
df['tipo_pension'] = pd.cut(df['pension'], bins=bins, labels=etiquetas)

# %%
df
# Out:
#             nombre     apellido  edad  discapacidad  pension  \
# 0          Antonio   Sannicolas    70             1    37597
# 1             Jose  Olloquiegui    99             0    13842
# 2           Manuel       Vinent    68             1    23492
# 3        Francisco    Francesch    76             1    37738
# 4             Juan     Calcines    96             0     9287
# ...            ...          ...   ...           ...      ...
# 49995        Tomas      Bu√Ëuel    89             0     9064
# 49996      Agustin      Luchena    86             0    21860
# 49997    Guillermo      Perdomo    65             1    36849
# 49998      Gabriel     Baraldes    84             0    28574
# 49999  Jose Miguel       Goiria    90             1    15732
#
#        familia_numerosa edad_hijo trabaja_hijo  lista_espera estado_civil  \
# 0                     1        22            1             0     casado/a
# 1                     0      None         None             2     casado/a
# 2                     0      None         None             0    soltero/a
# 3                     1        15         None             2     casado/a
# 4                     0      None         None             0      viudo/a
# ...                 ...       ...          ...           ...          ...
# 49995                 0      None         None             2     casado/a
# 49996                 1        17         None             1    soltero/a
# 49997                 0      None         None             2     casado/a
# 49998                 0      None         None             0     casado/a
# 49999                 0      None         None             0     casado/a
#
#        años_ant  vehiculo  hab_individual mobilidad enfermedad     sexo  \
# 0             1         1               1     media       None     male
# 1             2         1               1     media       None     male
# 2             0         0               0     media       None     male
# 3             1         1               1  limitada       None     male
# 4             1         1               0  limitada       None     male
# ...         ...       ...             ...       ...        ...      ...
# 49995         0         1               0     media       None     male
# 49996         0         0               1  perfecta       None     male
# 49997         2         1               0  perfecta       None     male
# 49998         2         0               0     media       None     male
# 49999         0         1               1  limitada       None  unknown
#
#                     trabajo tipo_pension
# 0                Camarero/a            J
# 1               Fontanero/a            B
# 2                Profesor/a            G
# 3              Electricista            J
# 4               Enfermero/a            A
# ...                     ...          ...
# 49995  Comercial/Vendedor/a            A
# 49996  Comercial/Vendedor/a            F
# 49997            Cocinero/a            J
# 49998           Fontanero/a            I
# 49999            Camarero/a            C
#
# [50000 rows x 18 columns]
